# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
iris_data=pd.read_csv('Iris.csv')
iris_data
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
SepalLengthCm=np.arange(0,10)
Species=np.arange(11,21)

# %%
plt.scatter(iris_data['SepalLengthCm'], iris_data['Species'], c='g')
plt.xlabel('X axis')
plt.ylabel('Y axis')
plt.title('Graph in 2D')
# Out:
# Text(0.5, 1.0, 'Graph in 2D')

# %%
Species = SepalLengthCm*SepalLengthCm

# %%
plt.plot(iris_data['SepalLengthCm'], iris_data['SepalWidthCm'], 'r*', linestyle='dashed', linewidth=2, markersize=12)
plt.xlabel('X axis')
plt.ylabel('Y axis')
plt.title('2d Diagram')
# Out:
# Text(0.5, 1.0, '2d Diagram')

# %%
plt.subplot(2, 2, 1)
plt.plot(iris_data['SepalLengthCm'], iris_data['SepalWidthCm'], 'r--')
plt.subplot(2, 2, 2)
plt.plot(iris_data['SepalLengthCm'], iris_data['SepalWidthCm'], 'g*--')
plt.subplot(2, 2, 3)
plt.plot(iris_data['SepalLengthCm'], iris_data['SepalWidthCm'], 'bo')
plt.subplot(2, 2, 4)
plt.plot(iris_data['SepalLengthCm'], iris_data['SepalWidthCm'], 'g--')

# %%
SepalLengthCm = np.arange(1, 11)
Species = 3 * SepalLengthCm + 5

# Plotting the function
plt.title("Matplotlib demo")
plt.xlabel("x axis caption")
plt.ylabel("y axis caption")
plt.plot(SepalLengthCm, Species)

# %%
np.pi
# Out:
# 3.141592653589793

# %%
# Compute the x and y coordinates for points on a sine curve
SepalLengthCm = np.arange(0, 4 * np.pi)
Species = np.sin(SepalLengthCm)
plt.title("sine wave form")

# Plot the points using matplotlib
plt.plot(SepalLengthCm, Species)

# %%
SepalLengthCm = np.arange(0, 5 * np.pi, 0.1)
y_sin = np.sin(SepalLengthCm)
y_cos = np.cos(SepalLengthCm)

# Set up a subplot grid that has height 2 and width 1,
# and set the first such subplot as active.
plt.subplot(2, 1, 1)

# Make the first plot
plt.plot(SepalLengthCm, y_sin,'r--')
plt.title('Sine')

# Set the second subplot as active, and make the second plot.
plt.subplot(2, 1, 2)
plt.plot(SepalLengthCm, y_cos,'g--')
plt.title('Cosine')

# Show the figure.
plt.show()

# %%
## Bar plot

SepalLengthCm = [2,8,10]
Species = [11,16,9]

x2 = [3,9,11]
y2 = [6,15,7]
plt.bar(SepalLengthCm, Species)
plt.bar(x2, y2, color = 'g')
plt.title('Bar graph')
plt.ylabel('Y axis')
plt.xlabel('X axis')

plt.show()
